# %% [markdown]
# # Word frequencies, overall and by time period

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl
# %matplotlib inline

# %%
import operator

def get_word_frequencies(cleaned_texts):
    
    word_use = {}
    for text in cleaned_texts:
        for word in text:
            if word not in word_use:
                word_use[word] = 0
            if word in word_use:
                word_use[word] += 1
    
    total_words = sum(word_use.values())
    
    sorted_words = sorted(word_use.items(), key=operator.itemgetter(1))
    sorted_words.reverse()
    
    print("Total number of documents: " + str(len(cleaned_texts)))
    print("Average length of text: " + str(np.mean([len(text) for text in cleaned_texts])))
    print(" ")
    print("The top 20 most used words:")
    print(sorted_words[0:20])
    print(" ")

    return word_use

# %%
def plot_relative_word_freq(word_freq_dict, target_words):
    
    fig, ax = plt.subplots(1, 2, figsize = (12, 5))
    
    ax[0].hist([v for v in word_freq_dict.values()], bins = 100, log = True)
    ax[0].set_xlabel('word frequency')
    ax[0].set_ylabel('number of words')
    
    freqs = [freq for freq in word_freq_dict.values()]
    
    max_freq = max(freqs)
    min_freq = min(freqs)
    
    for word in target_words:
        if word in word_freq_dict:
            ax[0].plot([word_freq_dict[word], word_freq_dict[word]], [0, max_freq], c='r')
            
    percentiles = [100*sum(i <= word_freq_dict[word] for i in freqs)/len(freqs) if word in word_freq_dict else 0 for word in target_words]
    
    y = np.arange(len(target_words))
    bars = ax[1].barh(target_words, percentiles)
    ax[1].bar_label(bars, labels = [str(word_freq_dict[word]) if word in word_freq_dict else '0' for word in target_words])
    ax[1].set_xlabel('word frequency percentile')
    
    fig.set_tight_layout(True)

    return fig, ax

# %% [markdown]
# ## Word frequencies by time period

# %%
import uv
from importlib import reload

# %%
reload(uv)
# Out:
# <module 'uv' from '/Users/cdeljunco/2-Work/Projects/AI-Scifi/Code/UtopianVectors/uv.py'>

# %%
book_info_eutopia, book_info_dystopia = uv.load_clean_metadata()

# %%
cln_txts_eu_dict, cln_txts_dys_dict = uv.get_text_dicts()
# Out:
# note: does not include scanned pdfs

# %%
#define time periods -- centuries from 1500 - 1800, decades from 1800 - 2021. Not principled, just based on 
#where we have data coverage. feel free to change/experiment

eras = list(np.arange(1500, 1801, 100)) + list(np.arange(1810, 2021, 10))
print(eras)

print("all time")
word_freq = get_word_frequencies(uv.get_all_texts(cln_txts_eu_dict))
fig, ax = plot_relative_word_freq(word_freq, uv.SEARCH_WORDS)
plt.suptitle("all time")

all_book_ids = []

for i in range(len(eras) - 1):
    print(eras[i], eras[i+1])
    word_freq = get_word_frequencies(uv.get_texts_year_range(eras[i], eras[i+1], book_info = book_info_eutopia, text_dict = cln_txts_eu_dict))
    fig, ax = plot_relative_word_freq(word_freq, uv.SEARCH_WORDS)
    plt.suptitle(str(eras[i]) + ' - ' + str(eras[i+1]))
# Out:
# [1500, 1600, 1700, 1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]
# all time
# Total number of documents: 721
# Average length of text: 30690.063800277392
#
# The top 20 most used words:
# [('�', 154845), ('said', 138875), ('man', 87335), ('like', 84593), ('time', 83207), ('people', 74479), ('great', 61827), ('men', 60446), ('life', 60402), ('know', 60095), ('o', 60089), ('world', 54898), ('way', 52476), ('little', 49836), ('good', 49823), ('new', 47727), ('come', 45045), ('day', 44900), ('work', 44089), ('f', 42639)]
#
# 1500 1600
# texts in date range: 2
# Total number of documents: 2
# Average length of text: 60161.5
#
# The top 20 most used words:
# [('m', 1983), ('selfe', 676), ('love', 641), ('unto', 516), ('said', 466), ('great', 440), ('good', 421), ('klm', 412), ('time', 404), ('man', 401), ('onely', 369), ('like', 365), ('having', 364), ('zelmane', 349), ('thy', 348), ('death', 347), ('arcadia', 344), ('eyes', 325), ('life', 322), ('owne', 322)]
#
# 1600 1700
# texts in date range: 8
# Total number of documents: 8
# Average length of text: 44621.875
#
# The top 20 most used words:
# [('fo', 2491), ('fuch', 1637), ('good', 1453), ('unto', 1407), ('god', 1360), ('great', 1324), ('men', 1258), ('hath', 1134), ('thofe', 1111), ('things', 1103), ('world', 1065), ('nature', 1026), ('fome', 1021), ('man', 1004), ('>', 987), ('j', 928), ('thefe', 894), ('holy', 893), ('people', 886), ('tbe', 839)]
#
# 1700 1800
# texts in date range: 13
# Total number of documents: 13
# Average length of text: 18270.846153846152
#
# The top 20 most used words:
# [('d', 1706), ('great', 1163), ('time', 934), ('man', 919), ('ſo', 741), ('s', 670), ('god', 618), ('found', 610), ('men', 610), ('little', 607), ('country', 586), ('good', 574), ('ſhe', 568), ('nature', 561), ('people', 519), ('fo', 508), ('travels', 506), ('having', 501), ('day', 493), ('young', 482)]
#
# 1800 1810
# texts in date range: 1
# Total number of documents: 1
# Average length of text: 22575.0
#
# The top 20 most used words:
# [('d', 959), ('s', 319), ('o', 140), ('er', 132), ('shall', 109), ('ev', 108), ('th', 92), ('n', 89), ('ry', 75), ('book', 75), ('light', 68), ('page', 68), ('chapter', 63), ('view', 58), ('heav', 55), ('thy', 55), ('long', 52), ('r', 51), ('hand', 51), ('eyes', 49)]
#
# 1810 1820
# texts in date range: 7
# Total number of documents: 7
# Average length of text: 22547.428571428572
#
# The top 20 most used words:
# [('man', 672), ('like', 596), ('country', 449), ('power', 436), ('people', 422), ('great', 415), ('world', 404), ('men', 401), ('earth', 362), ('state', 351), ('shall', 348), ('nature', 339), ('love', 336), ('thy', 335), ('time', 334), ('said', 321), ('light', 307), ('life', 300), ('day', 298), ('heart', 295)]
#
# 1820 1830
# texts in date range: 8
# Total number of documents: 8
# Average length of text: 21547.5
#
# The top 20 most used words:
# [('man', 1080), ('labour', 943), ('said', 682), ('great', 554), ('people', 547), ('men', 527), ('time', 497), ('land', 475), ('mind', 434), ('country', 431), ('like', 405), ('chapter', 400), ('nation', 388), ('little', 365), ('nature', 364), ('new', 364), ('money', 348), ('popanilla', 344), ('produce', 343), ('power', 339)]
#
# 1830 1840
# texts in date range: 5
# Total number of documents: 5
# Average length of text: 26654.8
#
# The top 20 most used words:
# [('man', 651), ('men', 537), ('new', 522), ('society', 489), ('human', 484), ('power', 473), ('great', 413), ('means', 390), ('state', 388), ('nature', 386), ('time', 370), ('life', 367), ('shall', 351), ('good', 332), ('world', 331), ('lord', 317), ('mind', 305), ('present', 299), ('laws', 297), ('system', 295)]
#
# 1840 1850
# texts in date range: 16
# Total number of documents: 16
# Average length of text: 46276.1875
#
# The top 20 most used words:
# [('man', 3209), ('great', 2872), ('nature', 2815), ('time', 2285), ('men', 1978), ('said', 1838), ('world', 1775), ('mind', 1767), ('like', 1759), ('life', 1616), ('new', 1593), ('s', 1555), ('good', 1479), ('things', 1432), ('present', 1432), ('human', 1385), ('day', 1385), ('earth', 1347), ('general', 1318), ('people', 1304)]
#
# 1850 1860
# texts in date range: 10
# Total number of documents: 10
# Average length of text: 34081.2
#
# The top 20 most used words:
# [('man', 1943), ('great', 1480), ('life', 1475), ('world', 1405), ('god', 1357), ('said', 1329), ('men', 1256), ('time', 1206), ('good', 1041), ('like', 984), ('power', 888), ('nature', 883), ('society', 875), ('shall', 860), ('new', 853), ('little', 820), ('day', 796), ('mind', 734), ('earth', 727), ('love', 714)]
#
# 1860 1870
# texts in date range: 8
# Total number of documents: 8
# Average length of text: 33418.625
#
# The top 20 most used words:
# [('ye', 2203), ('men', 1645), ('man', 1420), ('said', 1259), ('god', 1214), ('great', 1209), ('shall', 1187), ('people', 1165), ('good', 1066), ('hath', 1014), ('thou', 850), ('world', 821), ('thy', 786), ('jaido', 760), ('old', 748), ('life', 707), ('time', 695), ('forth', 681), ('let', 649), ('new', 636)]
#
# 1870 1880
# texts in date range: 22
# Total number of documents: 22
# Average length of text: 36117.818181818184
#
# The top 20 most used words:
# [('man', 3319), ('great', 3091), ('life', 2890), ('said', 2776), ('time', 2663), ('like', 2633), ('men', 2495), ('s', 2455), ('world', 2267), ('little', 1935), ('people', 1860), ('earth', 1719), ('good', 1686), ('work', 1680), ('new', 1669), ('love', 1546), ('day', 1545), ('god', 1531), ('old', 1366), ('long', 1315)]
#
# 1880 1890
# texts in date range: 52
# Total number of documents: 52
# Average length of text: 29594.03846153846
#
# The top 20 most used words:
# [('said', 10324), ('man', 8545), ('shall', 6969), ('great', 6067), ('time', 5977), ('earth', 5898), ('god', 5711), ('life', 5146), ('thou', 5115), ('men', 5112), ('people', 4957), ('like', 4362), ('thy', 4241), ('day', 4151), ('little', 4014), ('come', 3936), ('good', 3835), ('work', 3691), ('jehovih', 3542), ('world', 3500)]
#
# 1890 1900
# texts in date range: 105
# Total number of documents: 105
# Average length of text: 30952.44761904762
#
# The top 20 most used words:
# [('said', 15310), ('man', 14351), ('people', 13985), ('time', 13403), ('great', 12227), ('men', 12027), ('life', 10243), ('day', 9151), ('new', 8457), ('work', 8183), ('world', 7975), ('like', 7596), ('mr', 7497), ('good', 7392), ('little', 7075), ('way', 6832), ('shall', 6651), ('s', 6629), ('money', 6542), ('know', 6398)]
#
# 1900 1910
# texts in date range: 82
# Total number of documents: 82
# Average length of text: 29118.59756097561
#
# The top 20 most used words:
# [('said', 13841), ('man', 12380), ('people', 9257), ('time', 9171), ('men', 9099), ('great', 8885), ('life', 8387), ('like', 6716), ('shall', 6702), ('world', 6546), ('day', 6340), ('new', 6125), ('work', 5969), ('way', 5925), ('little', 5805), ('good', 5792), ('old', 5758), ('know', 5581), ('come', 5271), ('god', 5141)]
#
# 1910 1920
# texts in date range: 63
# Total number of documents: 63
# Average length of text: 27127.079365079364
#
# The top 20 most used words:
# [('o', 37276), ('f', 28965), ('s', 9632), ('e', 9583), ('said', 9217), ('man', 7950), ('b', 6272), ('great', 6230), ('life', 6132), ('time', 6073), ('men', 5499), ('like', 5197), ('n', 5152), ('r', 5102), ('t', 5102), ('h', 5016), ('people', 4793), ('little', 4559), ('world', 4361), ('new', 4008)]
#
# 1920 1930
# texts in date range: 23
# Total number of documents: 23
# Average length of text: 25098.130434782608
#
# The top 20 most used words:
# [('o', 9077), ('f', 6919), ('s', 3507), ('e', 3138), ('world', 2674), ('man', 2672), ('t', 2422), ('men', 2203), ('said', 2190), ('life', 1932), ('time', 1831), ('great', 1776), ('n', 1730), ('like', 1611), ('new', 1499), ('know', 1462), ('day', 1439), ('b', 1435), ('people', 1379), ('earth', 1310)]
#
# 1930 1940
# texts in date range: 24
# Total number of documents: 24
# Average length of text: 31072.833333333332
#
# The top 20 most used words:
# [('time', 3123), ('world', 2881), ('life', 2515), ('man', 2507), ('said', 2437), ('like', 2368), ('people', 2303), ('new', 2246), ('great', 2222), ('shall', 1795), ('men', 1700), ('work', 1679), ('little', 1571), ('way', 1531), ('know', 1486), ('human', 1456), ('long', 1398), ('system', 1358), ('old', 1317), ('paul', 1309)]
#
# 1940 1950
# texts in date range: 11
# Total number of documents: 11
# Average length of text: 23925.363636363636
#
# The top 20 most used words:
# [('said', 1484), ('man', 1183), ('people', 1161), ('time', 1095), ('like', 1031), ('world', 1003), ('life', 902), ('new', 888), ('know', 856), ('little', 797), ('good', 741), ('way', 733), ('work', 683), ('great', 642), ('long', 599), ('men', 592), ('day', 562), ('children', 558), ('old', 552), ('think', 544)]
#
# 1950 1960
# texts in date range: 9
# Total number of documents: 9
# Average length of text: 80272.66666666667
#
# The top 20 most used words:
# [('jesus', 4366), ('time', 3418), ('said', 3341), ('god', 3263), ('man', 3010), ('life', 2684), ('spirit', 2674), ('father', 2558), ('world', 2103), ('universe', 2082), ('human', 1809), ('spiritual', 1792), ('mind', 1765), ('know', 1734), ('like', 1687), ('master', 1670), ('great', 1568), ('new', 1543), ('men', 1453), ('paradise', 1449)]
#
# 1960 1970
# texts in date range: 22
# Total number of documents: 22
# Average length of text: 28871.772727272728
#
# The top 20 most used words:
# [('said', 6591), ('like', 3337), ('man', 2747), ('time', 2610), ('know', 2583), ('people', 2199), ('way', 2020), ('come', 1545), ('dasein', 1539), ('good', 1531), ('little', 1526), ('think', 1476), ('came', 1476), ('life', 1465), ('looked', 1406), ('thought', 1378), ('right', 1360), ('men', 1346), ('went', 1338), ('long', 1338)]
# /var/folders/zm/4xwl5pd57dnfqm16krd4ny1syhlqkc/T/ipykernel_74772/1976295466.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1, 2, figsize = (12, 5))
# 1970 1980
# texts in date range: 48
# Total number of documents: 48
# Average length of text: 28984.875
#
# The top 20 most used words:
# [('said', 14571), ('like', 8100), ('know', 5919), ('time', 4974), ('people', 4797), ('way', 4061), ('looked', 4042), ('right', 3941), ('come', 3887), ('think', 3686), ('thought', 3623), ('got', 3533), ('man', 3444), ('went', 3267), ('came', 3247), ('de', 3099), ('little', 3087), ('want', 3028), ('going', 2920), ('long', 2902)]
#
# 1980 1990
# texts in date range: 39
# Total number of documents: 39
# Average length of text: 38301.179487179485
#
# The top 20 most used words:
# [('said', 17748), ('like', 9073), ('know', 7109), ('time', 6023), ('people', 4665), ('e', 4656), ('way', 4617), ('come', 4019), ('think', 3850), ('t', 3683), ('little', 3676), ('s', 3671), ('thought', 3664), ('right', 3623), ('man', 3535), ('got', 3531), ('looked', 3519), ('came', 3445), ('long', 3330), ('away', 3246)]
#
# 1990 2000
# texts in date range: 47
# Total number of documents: 47
# Average length of text: 38299.31914893617
#
# The top 20 most used words:
# [('said', 15308), ('like', 11235), ('people', 7313), ('time', 6832), ('man', 6705), ('know', 6622), ('way', 5585), ('right', 4485), ('men', 4343), ('looked', 4313), ('little', 4304), ('thought', 4274), ('life', 4237), ('good', 4226), ('think', 4023), ('came', 3938), ('got', 3857), ('come', 3797), ('new', 3710), ('things', 3703)]
#
# 2000 2010
# texts in date range: 35
# Total number of documents: 35
# Average length of text: 23679.628571428573
#
# The top 20 most used words:
# [('said', 6012), ('like', 4242), ('time', 3241), ('people', 3183), ('know', 2818), ('way', 2476), ('work', 2237), ('think', 2014), ('going', 1992), ('looked', 1974), ('right', 1911), ('new', 1859), ('long', 1798), ('thought', 1792), ('good', 1716), ('world', 1677), ('come', 1661), ('away', 1657), ('little', 1642), ('came', 1631)]
#
# 2010 2020
# texts in date range: 61
# Total number of documents: 61
# Average length of text: 23609.245901639344
#
# The top 20 most used words:
# [('�', 153650), ('ƃ', 30265), ('said', 11210), ('like', 9220), ('people', 5528), ('eric', 5430), ('know', 5232), ('time', 5231), ('way', 4090), ('shit', 3885), ('right', 3652), ('got', 3487), ('think', 3335), ('come', 3125), ('good', 3035), ('looked', 2987), ('little', 2841), ('hand', 2791), ('going', 2769), ('says', 2681)]
